# %%
# 挂在云盘
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "/content/drive/MyDrive/Colab Notebooks/dlclass_data"
# Out:
# /content/drive/MyDrive/Colab Notebooks/dlclass_data

# %%
#Sentence-BERT+svm——【Test set accuracy: 0.62475】
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from scipy.spatial.distance import cosine, euclidean

# 读取数据集
def load_data(file_path):
    df = pd.read_csv(file_path, sep='\t')
    return df

# 提取句子的嵌入
def get_sentence_embeddings(model, sentences):
    embeddings = model.encode(sentences, convert_to_tensor=True)
    return embeddings.cpu().numpy()

# 构造特征
def create_features(embeddings1, embeddings2):
    # 计算向量差值
    diff = np.abs(embeddings1 - embeddings2)
    # 计算点积
    dot_product = np.sum(embeddings1 * embeddings2, axis=1)
    # 计算余弦相似度
    cosine_similarity = np.array([1 - cosine(a, b) for a, b in zip(embeddings1, embeddings2)])
    # 计算欧氏距离
    euclidean_distance = np.array([euclidean(a, b) for a, b in zip(embeddings1, embeddings2)])
    # 拼接特征
    features = np.column_stack((diff, dot_product, cosine_similarity, euclidean_distance))
    return features, cosine_similarity  # 返回特征和余弦相似度

# 主函数
def main():
    # 加载数据
    train_data = load_data('/content/drive/MyDrive/Colab Notebooks/dlclass_data/train.tsv')
    dev_data = load_data('/content/drive/MyDrive/Colab Notebooks/dlclass_data/dev.tsv')
    test_data = load_data('/content/drive/MyDrive/Colab Notebooks/dlclass_data/test.tsv')

    # 加载 Sentence-BERT 模型
    model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

    # 提取训练集嵌入
    train_embeddings1 = get_sentence_embeddings(model, train_data['sentence1'].tolist())
    train_embeddings2 = get_sentence_embeddings(model, train_data['sentence2'].tolist())

    # 提取验证集和测试集嵌入
    dev_embeddings1 = get_sentence_embeddings(model, dev_data['sentence1'].tolist())
    dev_embeddings2 = get_sentence_embeddings(model, dev_data['sentence2'].tolist())
    test_embeddings1 = get_sentence_embeddings(model, test_data['sentence1'].tolist())
    test_embeddings2 = get_sentence_embeddings(model, test_data['sentence2'].tolist())

    # 构造训练集特征
    X_train, _ = create_features(train_embeddings1, train_embeddings2)
    y_train = train_data['label'].values

    # 构造验证集和测试集特征
    X_dev, _ = create_features(dev_embeddings1, dev_embeddings2)
    y_dev = dev_data['label'].values

    X_test, test_cosine_similarity = create_features(test_embeddings1, test_embeddings2)
    y_test = test_data['label'].values

    # 标准化特征
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_dev = scaler.transform(X_dev)
    X_test = scaler.transform(X_test)

    # 训练 SVM
    svm = SVC(kernel='rbf', C=1.0, class_weight='balanced', probability=True)
    svm.fit(X_train, y_train)

    # 验证集性能
    y_dev_pred = svm.predict(X_dev)

    # 测试集性能
    y_test_pred = svm.predict(X_test)

    # 输出测试集预测结果
    print("\nTest set predictions:")
    for idx in range(len(test_data)):
        print(f"Sentence 1: {test_data['sentence1'].iloc[idx]}")
        print(f"Sentence 2: {test_data['sentence2'].iloc[idx]}")
        print(f"True label: {y_test[idx]}")
        print(f"Predicted label: {y_test_pred[idx]}")
        print(f"Cosine similarity: {test_cosine_similarity[idx]:.4f}")
        print("-" * 50)

    # 验证集性能
    print("Validation set performance:")
    print(classification_report(y_dev, y_dev_pred))

    # 测试集性能
    print("\nTest set performance:")
    print(classification_report(y_test, y_test_pred))
    print("Test set accuracy:", accuracy_score(y_test, y_test_pred))

if __name__ == '__main__':
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#Sentence-BERT+XGBoost————Test set accuracy: 0.625625
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from xgboost import XGBClassifier
from scipy.spatial.distance import cosine, euclidean

# 读取数据集
def load_data(file_path):
    df = pd.read_csv(file_path, sep='\t')
    return df

# 提取句子的嵌入
def get_sentence_embeddings(model, sentences):
    embeddings = model.encode(sentences, convert_to_tensor=True)
    return embeddings.cpu().numpy()  # 转换为 NumPy 数组

# 增强特征构造
def create_features(embeddings1, embeddings2):
    # 计算向量差值
    diff = np.abs(embeddings1 - embeddings2)
    # 计算点积
    dot_product = np.sum(embeddings1 * embeddings2, axis=1)
    # 计算余弦相似度
    cosine_similarity = np.array([1 - cosine(a, b) for a, b in zip(embeddings1, embeddings2)])
    # 计算欧氏距离
    euclidean_distance = np.array([euclidean(a, b) for a, b in zip(embeddings1, embeddings2)])
    # 拼接特征：|emb1 - emb2|, emb1 * emb2, cosine, euclidean
    features = np.column_stack((diff, dot_product, cosine_similarity, euclidean_distance))
    return features

# 主函数
def main():
    # 加载数据
    train_data = load_data('train.tsv')
    dev_data = load_data('dev.tsv')
    test_data = load_data('test.tsv')

    # 加载预训练的 Sentence-BERT 模型
    model = SentenceTransformer('all-mpnet-base-v2')  # 使用更强大的嵌入模型

    # 提取训练集的句子嵌入
    train_embeddings1 = get_sentence_embeddings(model, train_data['sentence1'].tolist())
    train_embeddings2 = get_sentence_embeddings(model, train_data['sentence2'].tolist())

    # 提取验证集和测试集的句子嵌入
    dev_embeddings1 = get_sentence_embeddings(model, dev_data['sentence1'].tolist())
    dev_embeddings2 = get_sentence_embeddings(model, dev_data['sentence2'].tolist())
    test_embeddings1 = get_sentence_embeddings(model, test_data['sentence1'].tolist())
    test_embeddings2 = get_sentence_embeddings(model, test_data['sentence2'].tolist())

    # 创建训练集的特征
    X_train = create_features(train_embeddings1, train_embeddings2)
    y_train = train_data['label'].values

    # 创建验证集和测试集的特征
    X_dev = create_features(dev_embeddings1, dev_embeddings2)
    y_dev = dev_data['label'].values

    X_test = create_features(test_embeddings1, test_embeddings2)
    y_test = test_data['label'].values

    # 标准化特征
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_dev = scaler.transform(X_dev)
    X_test = scaler.transform(X_test)

    # 训练 XGBoost 分类器
    xgb = XGBClassifier(scale_pos_weight=len(y_train[y_train == 0]) / len(y_train[y_train == 1]),  # 平衡类别
                         n_estimators=100, max_depth=5, learning_rate=0.1, random_state=42)
    xgb.fit(X_train, y_train)

    # 在验证集上评估性能
    y_dev_pred = xgb.predict(X_dev)


    # 在测试集上评估性能
    y_test_pred = xgb.predict(X_test)


    # 输出测试集的句子、预测结果和真实标签
    print("\nTest set predictions:")
    for idx in range(len(test_data)):
        print(f"Sentence 1: {test_data['sentence1'].iloc[idx]}")
        print(f"Sentence 2: {test_data['sentence2'].iloc[idx]}")
        print(f"True label: {y_test[idx]}")
        print(f"Predicted label: {y_test_pred[idx]}")
        print("-" * 50)

    # 验证集
    print("Validation set performance:")
    print(classification_report(y_dev, y_dev_pred))

    # 测试集
    print("\nTest set performance:")
    print(classification_report(y_test, y_test_pred))
    print("Test set accuracy:", accuracy_score(y_test, y_test_pred))

if __name__ == '__main__':
    main()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: They consist of nearly 30 expatriates , some members of the US Communist Party , while others are English writers or left-wing teachers .
# Sentence 2: They consist of nearly 30 expatriates , some members of the US Communist Party while others are English writers or leftist teachers .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The grass is growing in the Masirah Channel , a waterway between Oman and Masirah Island on the mainland , where it is an important food for the green sea turtle .
# Sentence 2: The grass grows in the Masirah Channel , a waterway between Masirah Island and mainland Oman , where it is an important food for the green sea turtle .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Panaon Island is a small island in the Philippines , in the province of Southern Leyte .
# Sentence 2: Leyte is a small island in the Philippines , in the province of Panaon Island .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Villa Pesquera facilities are operated by the Municipality of Ponce , but owned by the fishermen themselves .
# Sentence 2: The Villa Pesquera facilities are owned by the Municipality of Ponce , but are operated by the fishermen themselves .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: There are quite a number of festivals and traditions in Catalonia ( Spain ) .
# Sentence 2: In Catalonia ( Spain ) there are a number of festivals and traditions .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: She received her first Takarazuka Bow Hall Show in 1995 ( `` Grand Shanghai '' ) and in 1997 the second `` Wuthering Heights '' .
# Sentence 2: She got her second Takarazuka Bow Hall show ( `` Grand Shanghai '' ) in 1995 and the first one ( `` Wuthering Heights '' ) in 1997 .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He always added his own surname to Bhosle and treated the child like his own son afterwards .
# Sentence 2: He always added his own surname of Bhosle and afterwards treated the child like his own son .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Philippe Maystadt was born in Belgium in 1948 ( Verviers ) .
# Sentence 2: Philippe Maystadt was born 1948 in Verviers , Belgium .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: St. Meinrad became an abbey in 1870 , with Martin Marty as abbot and Fintan Mundwiler as a prior .
# Sentence 2: In 1870 , St. Meinrad became an abbey , Fintan Mundwiler , and Martin Marty as prior .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Charlotte Copperheads , the other lacrosse team of Charlotte , plays the indoor version of the game , the Box Lacrosse , in the Professional Lacrosse League .
# Sentence 2: Charlotte 's indoor lacrosse team , the Charlotte Copperheads , plays the other version of the game , box lacrosse , in the Professional Lacrosse League .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Windows XP - Mode executes Windows XP on a virtual machine and displays applications in separate windows on the Windows 7 desktop .
# Sentence 2: Windows XP Mode runs Windows XP in a separate machine , and displays applications within virtual windows on the Windows 7 desktop .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He dated John F. Kennedy ( who was later to marry Jacqueline Bouvier and become First Lady of the United States .
# Sentence 2: He dated Jacqueline Bouvier ( who was later to get married John F. Kennedy and become First Lady of the United States .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: It occurs in mountainous areas of Venezuela , Colombia and Ecuador , in humid forests at altitudes of between .
# Sentence 2: It occurs in mountainous areas of Ecuador , Colombia and Venezuela , in humid forests at altitudes between .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: `` Born Again '' is the twenty-second episode of the first season of American Science - Fiction - TV series '' The X-Files '' .
# Sentence 2: `` Born Again '' is the twenty-first episode of the second season of American science - fiction - television series '' The X-Files '' .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: He was the son of Thomas Corker , and a member of the Caulker family , descendents of Thomas Stephen Caulker .
# Sentence 2: He was the son of Thomas Stephen Caulker and a member of the Caulker family , a descendant of Thomas Corker .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The orbital is the same as the orbital , but the and are formed by taking linear
# Sentence 2: The Orbital is the same as the Orbital , but that and are formed by taking linear .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Chame Airport ( LID : MP24 ) is an airport serving the province of PanamÃø Oeste , a district of Chame district in Panama .
# Sentence 2: Chame Airport ( LID : MP24 ) is an airport serving the district Chame , a district in the Panama Oeste province of Panama .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: She has produced about 25 -- 30 films along with her husband Rajasri under the banners of Sri Rajarajeswari films , Kadaru Nagabhushanam pictures and Sri Varalakshmi films .
# Sentence 2: She produced together with her husband Rajasri about 25 -- 30 films under the banners of Sri Rajarajeswari films , Kadaru Nagabhushanam images and Sri Varalakshmi films .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: It was designed by local engineer Joseph H. Howe and designed by local builder Martin Johnson .
# Sentence 2: It was designed by local engineer Joseph H. Howe , and constructed by local builder Martin Johnson .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The band 's second album , `` Shine '' , was recorded between two general data sets and released in 2009 .
# Sentence 2: `` Shine '' , the band 's second album , was recorded between two general dates and released in 2009 .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He showed Cliff Robertson as Philip Nolan , Beau Bridges as Frederick Ingham , Peter Strauss as Arthur Danforth , Robert Ryan as Lt. Cmdr .
# Sentence 2: It featured Philip Nolan as Robert Ryan , Beau Bridges as Frederick Ingham , Peter Strauss as Arthur Danforth , and Cliff Robertson as Lt. Cmdr .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: At the bottom of the hydrometer there is a small lamp bulb and at the top is a pan for weights .
# Sentence 2: At the bottom of the hydrometer there is a weighted light bulb and a pan at the top for small weights .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Pola de Laviana is the capital of the municipality of Laviana .
# Sentence 2: Moreover , Pola de Laviana is the capital of the Laviana municipality .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Although Ned Hanlon hoped to be selected as John Ganzel 's successor as Cincinnati 's manager after the 1907 season , the Reds instead went with Huggins .
# Sentence 2: Although Huggins hoped to be elected as Cincinnati 's manager after the 1907 season as the successor of Ned Hanlon , the reds went with John Ganzel instead .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Other regions believed free of CSF include Ireland ( 1962 ) , Australia , Canada , New Zealand and Scandinavia .
# Sentence 2: Other regions believed to be free of CSF include Ireland ( 1962 ) , Australia , Canada , New Zealand , and Scandinavia .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Lorna Saycon Espina , the ninth mayor , is the incumbent mayor of the Municipality of Mahayag .
# Sentence 2: Lorna Saycon Espina , the 9th mayor , is the incumbent Municipal Mayor of the Municipality of Mahayag .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The first formal description of the Vietnamese greenfinch was by the American ornithologist Jean Théodore Delacour in 1926 under the binomial name `` Hypacanthis monguilloti '' .
# Sentence 2: The first formal description of the American green fink was given in 1926 by the Vietnamese ornithologist Jean Théodore Delacour under the binomial name of `` Hypacanthis monguilloti '' .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Later , as he promised , Vishnu married Lakshmi .
# Sentence 2: Later Vishnu married Lakshmi as he promised .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: US 222 and PA 724 meet in Spring Township and both meet US 422 in Wyomissing and Sinking Spring , respectively .
# Sentence 2: The US 222 and PA 724 meet in Spring Township and both meet in Wyomissing and Sinking Spring on the US 422 .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He was born in New York City in East Broadway on October 23 , 1806 .
# Sentence 2: He was born on 23 October 1806 in East Broadway , New York .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Baldwins lived in Washington , D.C. Helen Baldwin died in 1977 , and Robert Baldwin died from the disease of Lou Gehrig on March 14 , 1998 .
# Sentence 2: The Baldwins lived in Washington , D.C. Robert Baldwin died in 1977 , and Helen Baldwin died from the disease of Lou Gehrig on 14 March 1998 .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The academic structure of the new institution included the Faculties for Medicine , Law , Chemistry and Business .
# Sentence 2: The new structure of the academic institution included the faculties of Medicine , Law , Chemistry and Business .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1:

# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: However , he criticized the other campaign , `` some of the misrepresentations by the conservative candidate had not been cricket .
# Sentence 2: However he criticised the other campaign , `` some of the misrepresentations by the Conservative candidate had not been cricket . ''
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The Rondônia ( Juruá River ) is a river of Rondônia state in western Brazil .
# Sentence 2: The Rondônia ( Juruá - River ) is a river in the state of Rondônia in western Brazil .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Hunt returned to New York until 1976 when he moved to Venice , California .
# Sentence 2: Hunt returned to New York until he moved to Venice in 1976 , California .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: He served in the 11th Congress and in the 12th Congress .
# Sentence 2: He served in the 12th Congress and in the 11th Congress .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: 43.0 % were German , 10.8 % Norwegian , 8.3 % Irish , 7.4 % of Finnish and 5.9 % Swedish descent according to the 2000 census .
# Sentence 2: 43.0 % were of German , 10.8 % Norwegian , 8.3 % Irish , 7.4 % Finnish and 5.9 % Swedish ancestry according to Census 2000 .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Limited Growth is a trance collaboration between Frederico Santini & Axel Stephenson .
# Sentence 2: Growth is a trance - collaboration between Axel Stephenson and Frederico Santini .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Stations like Coimbatore , Coimbatore Nord , Thudiyalur , Periyanaickenpalayam , Karamadai , Mettupalayam are on this line.Suburban areas are connected by this line .
# Sentence 2: Stations like Coimbatore , Coimbatore North , Thudiyalur , Periyanaickenpalayam , Karamadai , Mettupalayam are on this line.Suburban areas are connected by this line .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Bojan Krasić ( ; born 4 January 1983 ) is a Serbian football defender . He is a brother of Miloš Krasić .
# Sentence 2: Miloš Krasić ( born January 4 , 1983 ) is a Serbian football defender who is a brother of Bojan Krasić .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Rodman Wanamaker deserves recognition for securing the Wanamaker patronage for the elaborate store - concerts , both in New York and Philadelphia between 1919 and Russell 's death in 1928 .
# Sentence 2: Dr. Rodman Wanamaker deserves credit for securing Wanamaker patronage for the elaborate store concerts , both in New York and Philadelphia between 1919 and Russell 's death in 1928 .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: It has been shown that the tolerance of human stereopsis to cyclodisparity of lines ( orientation disparity ) is greater for horizontal lines than for vertical lines .
# Sentence 2: It has been demonstrated that the tolerance of human stereopsis over the cyclodisparity of lines ( orientation disparity ) for vertical lines is greater than for horizontal lines .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Rhododendron arboreum , the tree rhododendron , also known as Burans or Gurans , is an evergreen shrub or striking tree with a small display of bright red flowers .
# Sentence 2: Rhododendron arboreum , the tree rhododendron , also known as burans or gurans , is an evergreen shrub or showy tree with a small display of bright red flowers .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Dodrill was named to the NFL Pro Bowl four times ( 1954 , 1955 , 1956 , 1958 ) and voted First Team All-Pro in 1954 .
# Sentence 2: Dodrill was elected four times the NFL Pro Bowl ( 1954 , 1955 , 1956 , 1958 ) and First Team All-Pro in 1954 .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: She began the practice of grouping the students with the same language problem and teaching them together .
# Sentence 2: She began the practice of teaching students with the same speech problem and grouping them together .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: John Hart ( also known as James Lee Hart , born c. 1944 ) is an American political activist .
# Sentence 2: John Hart ( also known as James Lee Hart , born 1944 ) is an American political activist .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: He was a fellow of the Royal Colonial Institute , the Royal Geographic Society , and the Royal Statistical Society ( RGS ) .
# Sentence 2: He was fellow of the Royal Colonial Institute , the Royal Geographic Society and the Royal Statistical Society ( RGS ) .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Meanwhile , the Vichy regime has promoted a highly traditional model of female roles .
# Sentence 2: Meanwhile , the Vichy regime has promoted a highly female model of traditional roles .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Norman Bailey retained his place for the following game , but the captain moved to Hunter .
# Sentence 2: For the following game , Norman Bailey retained his place but the captaincy moved to Hunter .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: In 1994 , Smith Smith returned to SummerSlam to WWF , where he immediately became involved in an ongoing family feud between Bret Hart and his brother Owen Hart .
# Sentence 2: Bret Hart returned to the WWF at SummerSlam in 1994 , where he immediately became involved in an ongoing family feud between Smith and his brother , Owen Hart .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The dazzling rhythms of the interior have a complex geometry .
# Sentence 2: The dazzling rhythms of the interior have a complex geometry to them .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: In 1950 , Small sold a package of 26 movies that he produced to show on American television through his Peerless Television Productions .
# Sentence 2: In 1950 Small produced a package of 26 films he sold to show on American television through his Peerless Television Productions .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Kumar advises you to take starts from Premji by paying large amounts of money .
# Sentence 2: Kumar advises to take starts from Premji by paying large amounts of money .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Shabbily Paul Paul revealed that Jason had only been stunned , and Jason had lied to Elizabeth to get blackmail money .
# Sentence 2: Paul sheepishly revealed that Jason had only been stunned , and Jason had lied to Elizabeth to get blackmail money .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Born in Shelby County , Alabama , Sawyer moved with his parents to Lee County , Mississippi .
# Sentence 2: Sawyer was born in Shelby County , Alabama , and moved to Lee County , Mississippi with his parents .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The band recorded an EP with Habeas Corpus , a song with Juan ( Agnostic Front ) and another with Roger Miret ( Soziedad Alcoholika ) in 2010 .
# Sentence 2: The band recorded an EP with Habeas Corpus in 2010 , a song with Roger Miret ( Agnostic Front ) and another one with Juan ( Soziedad Alkoholika )
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: His published works include a series of sermons written in `` Old Yet Ever New '' ( 1904 ) and `` Dayspring From On High '' ( 1907 ) .
# Sentence 2: His written works include a number of sermons published in `` Old Yet Ever New '' ( 1904 ) and `` Dayspring From On High '' ( 1907 ) .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Windsor -- Tecumseh was created in 2003 from parts of Windsor and the Essex -- St. Clair ridings .
# Sentence 2: Windsor -- Tecumseh was created in 2003 from parts of Windsor and the Essex -- St. Clair cattle .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The US 222 and the PA 724 meet in Spring Township and both meet in Wyomissing and Sinking Spring on US 422 .
# Sentence 2: US 222 and PA 724 meet in Spring Township and both meet US 422 in Wyomissing and Sinking Spring , respectively .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: `` Shine '' , the band 's second album , was released between two general dates and recorded 2009 .
# Sentence 2: The band 's second album , `` Shine '' , was recorded between two general data sets and released in 2009 .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Stefan Stefan would animate the `` Skumps '' sequence between Kings Hubert and John Lounsbery .
# Sentence 2: John Lounsbery would animate the `` Scumps '' sequence between Kings Hubert and Stefan .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He is also the brother of the writer Ralph Connor and grandson of the novelist Alison Gordon .
# Sentence 2: He is also the brother of writer Alison Gordon and the grandson of novelist Ralph Connor .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Where is invariant mass and invariant energy equals . The squared mass is still positive and the particle can be stable .
# Sentence 2: Where is invariant mass and invariant energy the same , the squared mass is still positive and the particle can be stable .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: In 1976 , Western Forge delivered its 100 millionth Craftsman screwdriver , in 2008 the company produced its billionth screwdriver .
# Sentence 2: In 1976 , Western Forge shipped its 100 millionth Craftsman screwdriver . In 2008 , the company produced its billionth screwdriver overall .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1

# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: After the Belgian Revolution of 1830 , the Southern Netherlands ( including South and Central Brabant ) became independent as Belgium and later also Luxembourg .
# Sentence 2: After the Belgian Revolution of 1830 , the South Netherlands ( including southern and central Brabant ) became independent as Belgium , and later Luxembourg .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Joshua Eagle and Andrew Florent won the title , defeating Sébastien Lareau and Jeff Tarango 6 -- 3 , 6 -- 2 in the final .
# Sentence 2: Sébastien Lareau and Jeff Tarango won the title and defeated Joshua Eagle and Andrew Florent with 6 -- 3 , 6 -- 2 in the final .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: This species occurs in the Pacific Ocean from Micronesia to Taiwan and from Thailand to Queensland , Australia .
# Sentence 2: This species is from Micronesia to Taiwan in the Pacific and from Thailand to Queensland , Australia .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Ruben Bolling ( * 1963 in New Jersey ) is a pseudonym for the cartoonist Ken Fisher , author of `` Tom the Dancing Bug '' .
# Sentence 2: Ken Fisher ( born c. 1963 in New Jersey ) is a pseudonym for Ruben Bolling , a cartoonist , the author of `` Tom the Dancing Bug '' .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: There are 2 further keys that differ in these 2 languages : Slovak key replaces the Czech key and Slovak key replaces the Czech key .
# Sentence 2: There are 2 more keys that differ in these 2 languages : Czech key replaces Czech key and Slovak key replaces Slovak key .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Of these eighteen countries , four of them have listed IN , PA , OH and MD `` G. villosa '' as endangered species .
# Sentence 2: Of these 18 states , four of them have listed IN , MD , OH and PA `` G. villosa '' as endangered species .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Java calls these types simple types , while they are called in C # `` Primitive Types '' .
# Sentence 2: Java calls these types primitive types , while they are called `` simple types '' in C # .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Soori is a 2001 Telugu film directed by debutant Sankara Kumar .
# Sentence 2: Soori is a 2001 Telugu movie directed by Debutant Sankara Kumar .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: James Alexander Hanson was born , the second son of James Trickett Hanson ( a Danish immigrant ) and Janet Scott .
# Sentence 2: Jim Marchbank was born James Alexander Hanson , the second son of James Trickett Hanson ( a Danish immigrant ) and Janet Scott .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Where formula _ 1 is the total surface energy of the solid , formula _ 1 and formula _ 1 are respectively the dispersive and polar components of the solid surface energy ,
# Sentence 2: Formula 1 is the solid surface energy of dispersive and polar , Formula 1 and Formula 1 respectively are the solid components of the overall surface energy .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Watchorn died on 3 April 1882 , and Fisher won the resulting May 1882 by-election comfortably .
# Sentence 2: Watchorn died on 3 April 1882 , and Fisher comfortably won the resulting May 1882 assistance .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: In Mississippi , unlike Alabama or Tennessee , MS 178 and US 78 are totally separate routes .
# Sentence 2: In Mississippi , MS 178 and US 78 are completely separate routes , unlike Alabama or Tennessee .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Twice Sparrow sold the island twice to Thomas Pollock , who would soon be the governor of North Carolina ( from 1712 to 1714 and again 1722 ) .
# Sentence 2: Sparrow twice sold the island to Thomas Pollock , who would soon be governor of North Carolina ( from 1712 to 1714 and again in 1722 ) .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Independencia is a central department of Chaco Province in Argentina .
# Sentence 2: Independencia is a central department of Argentina in the province of Chaco .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: She married Reinaldo Zamparelli in 1954 , living in Bogotá , Colombia and later in Lima , Peru .
# Sentence 2: In 1954 she married Reinaldo Zamparelli , lived in Lima , Peru and later in Bogotá , Colombia .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Nesby Phips appeared in the documentary `` Mystery Lights '' , produced by Nowhere Studios , presented by Converse and released in the UK December 4 , 2015 .
# Sentence 2: Nesby Phips was released in the documentary `` Mystery Lights '' , presented by Nowhere Studios , produced by Converse and published in the UK on December 4 , 2015 .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The name in Tupi means `` insensitive stone '' , `` hard stone '' or `` rest stone '' .
# Sentence 2: The name in Tupi means '' hard stone `` , '' insensitive stone `` or '' stone `` .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The company has branches in Tokyo , based in the Saitama prefecture .
# Sentence 2: The company has branches in Tokyo based in Saitama Prefecture .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Muara Teweh ( abbreviated : MTW ) is a city located in the province of North Barito Regency . It is the capital of Central Kalimantan .
# Sentence 2: Teweh ( abbreviated : MTW ) is a city located in the province of Central Kalimantan , the capital of North Barito Regency .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The modern coat of arms of Bavaria was designed by Eduard Ege in 1946 , following heraldic traditions .
# Sentence 2: The modern coat of arms of Bavaria was designed in 1946 by Eduard Ege according to heraldic traditions .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Former President , Brenda Kuecks , received a Clean50 Award in 2013 for her work in promoting clean development and sustainable capitalism in Canada .
# Sentence 2: In 2013 , former President Brenda Kuecks received a Clean50 Award for her work to promote sustainable development and clean capitalism in Canada .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: It is located near Point Pleasant Borough , a municipality of Point Pleasant Beach independent .
# Sentence 2: It is near Point Pleasant borough , a municipality independent of Point Pleasant Beach .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Validation set performance:
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68      4461
#            1       0.60      0.59      0.59      3539
#
#     accuracy                           0.64      8000
#    macro avg       0.64      0.64      0.64      8000
# weighted avg       0.64      0.64      0.64      8000
#
#
# Test set performance:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66      4464
#            1       0.58      0.59      0.58      3536
#
#     accuracy                           0.63      8000
#    macro avg       0.62      0.62      0.62      8000
# weighted avg       0.63      0.63      0.63      8000
#
# Test set accuracy: 0.625625

# %%
#Sentence-BERT+svm————Test set accuracy: 0.631375
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 读取数据集
def load_data(file_path):
    df = pd.read_csv(file_path, sep='\t')
    return df

# 提取句子的嵌入
def get_sentence_embeddings(model, sentences):
    # 获取嵌入并确保在CPU上
    embeddings = model.encode(sentences, convert_to_tensor=True)
    return embeddings.cpu().numpy()  # 转换为NumPy数组

# 特征组合：计算句子嵌入的差值、点积及拼接
def create_features(embeddings1, embeddings2):
    # 计算嵌入向量的差值
    diff = np.abs(embeddings1 - embeddings2)

    # 计算嵌入向量的点积
    dot_product = np.sum(embeddings1 * embeddings2, axis=1)

    # 特征拼接：|emb1 - emb2|, emb1 * emb2
    features = np.column_stack((diff, dot_product))

    return features

# 主函数
def main():
    # 加载数据
    train_data = load_data('train.tsv')
    dev_data = load_data('dev.tsv')
    test_data = load_data('test.tsv')

    # 加载预训练的Sentence-BERT模型
    model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

    # 提取训练集的句子嵌入
    train_embeddings1 = get_sentence_embeddings(model, train_data['sentence1'].tolist())
    train_embeddings2 = get_sentence_embeddings(model, train_data['sentence2'].tolist())

    # 提取验证集和测试集的句子嵌入
    dev_embeddings1 = get_sentence_embeddings(model, dev_data['sentence1'].tolist())
    dev_embeddings2 = get_sentence_embeddings(model, dev_data['sentence2'].tolist())
    test_embeddings1 = get_sentence_embeddings(model, test_data['sentence1'].tolist())
    test_embeddings2 = get_sentence_embeddings(model, test_data['sentence2'].tolist())

    # 创建训练集的特征
    X_train = create_features(train_embeddings1, train_embeddings2)
    y_train = train_data['label'].values

    # 创建验证集和测试集的特征
    X_dev = create_features(dev_embeddings1, dev_embeddings2)
    y_dev = dev_data['label'].values

    X_test = create_features(test_embeddings1, test_embeddings2)
    y_test = test_data['label'].values

    # 标准化特征
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_dev = scaler.transform(X_dev)
    X_test = scaler.transform(X_test)

    # 训练SVM模型
    svm = SVC(kernel='rbf', C=1, gamma='scale')
    svm.fit(X_train, y_train)

    # 在验证集上评估性能
    y_dev_pred = svm.predict(X_dev)


    # 在测试集上评估性能
    y_test_pred = svm.predict(X_test)

    # 输出测试集的句子、预测结果和真实标签
    print("\nTest set predictions:")
    for idx in range(len(test_data)):
        print(f"Sentence 1: {test_data['sentence1'].iloc[idx]}")
        print(f"Sentence 2: {test_data['sentence2'].iloc[idx]}")
        print(f"True label: {y_test[idx]}")
        print(f"Predicted label: {y_test_pred[idx]}")
        print("-" * 50)


    print("Validation set performance:")
    print(classification_report(y_dev, y_dev_pred))
    print("Dev set accuracy:", accuracy_score(y_test, y_test_pred))


    print("\nTest set performance:")
    print(classification_report(y_test, y_test_pred))
    print("Test set accuracy:", accuracy_score(y_test, y_test_pred))

if __name__ == '__main__':
    main()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: They consist of nearly 30 expatriates , some members of the US Communist Party , while others are English writers or left-wing teachers .
# Sentence 2: They consist of nearly 30 expatriates , some members of the US Communist Party while others are English writers or leftist teachers .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The grass is growing in the Masirah Channel , a waterway between Oman and Masirah Island on the mainland , where it is an important food for the green sea turtle .
# Sentence 2: The grass grows in the Masirah Channel , a waterway between Masirah Island and mainland Oman , where it is an important food for the green sea turtle .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Panaon Island is a small island in the Philippines , in the province of Southern Leyte .
# Sentence 2: Leyte is a small island in the Philippines , in the province of Panaon Island .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Villa Pesquera facilities are operated by the Municipality of Ponce , but owned by the fishermen themselves .
# Sentence 2: The Villa Pesquera facilities are owned by the Municipality of Ponce , but are operated by the fishermen themselves .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: There are quite a number of festivals and traditions in Catalonia ( Spain ) .
# Sentence 2: In Catalonia ( Spain ) there are a number of festivals and traditions .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: She received her first Takarazuka Bow Hall Show in 1995 ( `` Grand Shanghai '' ) and in 1997 the second `` Wuthering Heights '' .
# Sentence 2: She got her second Takarazuka Bow Hall show ( `` Grand Shanghai '' ) in 1995 and the first one ( `` Wuthering Heights '' ) in 1997 .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He always added his own surname to Bhosle and treated the child like his own son afterwards .
# Sentence 2: He always added his own surname of Bhosle and afterwards treated the child like his own son .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Philippe Maystadt was born in Belgium in 1948 ( Verviers ) .
# Sentence 2: Philippe Maystadt was born 1948 in Verviers , Belgium .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: St. Meinrad became an abbey in 1870 , with Martin Marty as abbot and Fintan Mundwiler as a prior .
# Sentence 2: In 1870 , St. Meinrad became an abbey , Fintan Mundwiler , and Martin Marty as prior .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Charlotte Copperheads , the other lacrosse team of Charlotte , plays the indoor version of the game , the Box Lacrosse , in the Professional Lacrosse League .
# Sentence 2: Charlotte 's indoor lacrosse team , the Charlotte Copperheads , plays the other version of the game , box lacrosse , in the Professional Lacrosse League .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Windows XP - Mode executes Windows XP on a virtual machine and displays applications in separate windows on the Windows 7 desktop .
# Sentence 2: Windows XP Mode runs Windows XP in a separate machine , and displays applications within virtual windows on the Windows 7 desktop .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He dated John F. Kennedy ( who was later to marry Jacqueline Bouvier and become First Lady of the United States .
# Sentence 2: He dated Jacqueline Bouvier ( who was later to get married John F. Kennedy and become First Lady of the United States .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: It occurs in mountainous areas of Venezuela , Colombia and Ecuador , in humid forests at altitudes of between .
# Sentence 2: It occurs in mountainous areas of Ecuador , Colombia and Venezuela , in humid forests at altitudes between .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: `` Born Again '' is the twenty-second episode of the first season of American Science - Fiction - TV series '' The X-Files '' .
# Sentence 2: `` Born Again '' is the twenty-first episode of the second season of American science - fiction - television series '' The X-Files '' .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: He was the son of Thomas Corker , and a member of the Caulker family , descendents of Thomas Stephen Caulker .
# Sentence 2: He was the son of Thomas Stephen Caulker and a member of the Caulker family , a descendant of Thomas Corker .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The orbital is the same as the orbital , but the and are formed by taking linear
# Sentence 2: The Orbital is the same as the Orbital , but that and are formed by taking linear .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Chame Airport ( LID : MP24 ) is an airport serving the province of PanamÃø Oeste , a district of Chame district in Panama .
# Sentence 2: Chame Airport ( LID : MP24 ) is an airport serving the district Chame , a district in the Panama Oeste province of Panama .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: She has produced about 25 -- 30 films along with her husband Rajasri under the banners of Sri Rajarajeswari films , Kadaru Nagabhushanam pictures and Sri Varalakshmi films .
# Sentence 2: She produced together with her husband Rajasri about 25 -- 30 films under the banners of Sri Rajarajeswari films , Kadaru Nagabhushanam images and Sri Varalakshmi films .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: It was designed by local engineer Joseph H. Howe and designed by local builder Martin Johnson .
# Sentence 2: It was designed by local engineer Joseph H. Howe , and constructed by local builder Martin Johnson .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The band 's second album , `` Shine '' , was recorded between two general data sets and released in 2009 .
# Sentence 2: `` Shine '' , the band 's second album , was recorded between two general dates and released in 2009 .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He showed Cliff Robertson as Philip Nolan , Beau Bridges as Frederick Ingham , Peter Strauss as Arthur Danforth , Robert Ryan as Lt. Cmdr .
# Sentence 2: It featured Philip Nolan as Robert Ryan , Beau Bridges as Frederick Ingham , Peter Strauss as Arthur Danforth , and Cliff Robertson as Lt. Cmdr .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: At the bottom of the hydrometer there is a small lamp bulb and at the top is a pan for weights .
# Sentence 2: At the bottom of the hydrometer there is a weighted light bulb and a pan at the top for small weights .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Pola de Laviana is the capital of the municipality of Laviana .
# Sentence 2: Moreover , Pola de Laviana is the capital of the Laviana municipality .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Although Ned Hanlon hoped to be selected as John Ganzel 's successor as Cincinnati 's manager after the 1907 season , the Reds instead went with Huggins .
# Sentence 2: Although Huggins hoped to be elected as Cincinnati 's manager after the 1907 season as the successor of Ned Hanlon , the reds went with John Ganzel instead .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Other regions believed free of CSF include Ireland ( 1962 ) , Australia , Canada , New Zealand and Scandinavia .
# Sentence 2: Other regions believed to be free of CSF include Ireland ( 1962 ) , Australia , Canada , New Zealand , and Scandinavia .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Lorna Saycon Espina , the ninth mayor , is the incumbent mayor of the Municipality of Mahayag .
# Sentence 2: Lorna Saycon Espina , the 9th mayor , is the incumbent Municipal Mayor of the Municipality of Mahayag .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1:

# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The 1992 National Football League season was the 73rd regular NFL season .
# Sentence 2: The 1992 National Football League season was the 73rd regular season of the NFL .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: It is also one of thirty-two traditional counties of Ulster and is within the province of Ireland .
# Sentence 2: It is also one of the thirty-two traditional counties of Ulster and is within the province of Ireland .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: `` a '' is 1 if either `` j '' divides 1 or `` i '' is `` j '' .
# Sentence 2: `` a '' is 1 if `` j '' is either 1 divided or `` i `` j '' .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Nationals wore the uniforms of the 1924 Washington Senators on July 5 against the New York Giants , who wore the 1924 Giants uniforms .
# Sentence 2: The Nationals wear the uniforms of the 1924 Washington Senators on July 5 against the Giants , who wore uniforms from the New York Giants in 1924 .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: It was originally named Riversfield but renamed after Don Hill , a former club chairman .
# Sentence 2: It was originally renamed Riversfield , but named after Don Hill , a former club chair .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Located in the Sacramento Valley , the 13th District Agricultural Association better known as the Yuba -- Sutter Fair is long on history and tradition .
# Sentence 2: Situated in the Sacramento Valley , the 13th district is agricultural association , better known as Yuba -- Sutter Fair , long history and tradition .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: This means that the homotopic equivalence between M , W and N is homotopically a C-isomorphism .
# Sentence 2: This means that the homotopic equivalence between M , W , and N is homotopy to a C-isomorphism .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: However , he criticized the other campaign , `` some of the misrepresentations by the conservative candidate had not been cricket .
# Sentence 2: However he criticised the other campaign , `` some of the misrepresentations by the Conservative candidate had not been cricket . ''
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Rondônia ( Juruá River ) is a river of Rondônia state in western Brazil .
# Sentence 2: The Rondônia ( Juruá - River ) is a river in the state of Rondônia in western Brazil .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Hunt returned to New York until 1976 when he moved to Venice , California .
# Sentence 2: Hunt returned to New York until he moved to Venice in 1976 , California .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He served in the 11th Congress and in the 12th Congress .
# Sentence 2: He served in the 12th Congress and in the 11th Congress .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: 43.0 % were German , 10.8 % Norwegian , 8.3 % Irish , 7.4 % of Finnish and 5.9 % Swedish descent according to the 2000 census .
# Sentence 2: 43.0 % were of German , 10.8 % Norwegian , 8.3 % Irish , 7.4 % Finnish and 5.9 % Swedish ancestry according to Census 2000 .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Limited Growth is a trance collaboration between Frederico Santini & Axel Stephenson .
# Sentence 2: Growth is a trance - collaboration between Axel Stephenson and Frederico Santini .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Stations like Coimbatore , Coimbatore Nord , Thudiyalur , Periyanaickenpalayam , Karamadai , Mettupalayam are on this line.Suburban areas are connected by this line .
# Sentence 2: Stations like Coimbatore , Coimbatore North , Thudiyalur , Periyanaickenpalayam , Karamadai , Mettupalayam are on this line.Suburban areas are connected by this line .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Bojan Krasić ( ; born 4 January 1983 ) is a Serbian football defender . He is a brother of Miloš Krasić .
# Sentence 2: Miloš Krasić ( born January 4 , 1983 ) is a Serbian football defender who is a brother of Bojan Krasić .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Rodman Wanamaker deserves recognition for securing the Wanamaker patronage for the elaborate store - concerts , both in New York and Philadelphia between 1919 and Russell 's death in 1928 .
# Sentence 2: Dr. Rodman Wanamaker deserves credit for securing Wanamaker patronage for the elaborate store concerts , both in New York and Philadelphia between 1919 and Russell 's death in 1928 .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: It has been shown that the tolerance of human stereopsis to cyclodisparity of lines ( orientation disparity ) is greater for horizontal lines than for vertical lines .
# Sentence 2: It has been demonstrated that the tolerance of human stereopsis over the cyclodisparity of lines ( orientation disparity ) for vertical lines is greater than for horizontal lines .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Rhododendron arboreum , the tree rhododendron , also known as Burans or Gurans , is an evergreen shrub or striking tree with a small display of bright red flowers .
# Sentence 2: Rhododendron arboreum , the tree rhododendron , also known as burans or gurans , is an evergreen shrub or showy tree with a small display of bright red flowers .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Dodrill was named to the NFL Pro Bowl four times ( 1954 , 1955 , 1956 , 1958 ) and voted First Team All-Pro in 1954 .
# Sentence 2: Dodrill was elected four times the NFL Pro Bowl ( 1954 , 1955 , 1956 , 1958 ) and First Team All-Pro in 1954 .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: She began the practice of grouping the students with the same language problem and teaching them together .
# Sentence 2: She began the practice of teaching students with the same speech problem and grouping them together .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: John Hart ( also known as James Lee Hart , born c. 1944 ) is an American political activist .
# Sentence 2: John Hart ( also known as James Lee Hart , born 1944 ) is an American political activist .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: He was a fellow of the Royal Colonial Institute , the Royal Geographic Society , and the Royal Statistical Society ( RGS ) .
# Sentence 2: He was fellow of the Royal Colonial Institute , the Royal Geographic Society and the Royal Statistical Society ( RGS ) .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Meanwhile , the Vichy regime has promoted a highly traditional model of female roles .
# Sentence 2: Meanwhile , the Vichy regime has promoted a highly female model of traditional roles .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Norman Bailey retained his place for the following game , but the captain moved to Hunter .
# Sentence 2: For the following game , Norman Bailey retained his place but the captaincy moved to Hunter .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: In 1994 , Smith Smith returned to SummerSlam to WWF , where he immediately became involved in an ongoing family feud between Bret Hart and his brother Owen Hart .
# Sentence 2: Bret Hart returned to the WWF at SummerSlam in 1994 , where he immediately became involved in an ongoing family feud between Smith and his brother , Owen Hart .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The dazzling rhythms of the interior have a complex geometry .
# Sentence 2: The dazzling rhythms of the interior have a complex geometry to them .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: In 1950 , Small sold a package of 26 movies that he produced to show on American television through his Peerless Television Productions .
# Sentence 2: In 1950 Small produced a package of 26 films he sold to show on American television through his Peerless Television Productions .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Kumar advises you to take starts from Premji by paying large amounts of money .
# Sentence 2: Kumar advises to take starts from Premji by paying large amounts of money .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Shabbily Paul Paul revealed that Jason had only been stunned , and Jason had lied to Elizabeth to get blackmail money .
# Sentence 2: Paul sheepishly revealed that Jason had only been stunned , and Jason had lied to Elizabeth to get blackmail money .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Born in Shelby County , Alabama , Sawyer moved with his parents to Lee County , Mississippi .
# Sentence 2: Sawyer was born in Shelby County , Alabama , and moved to Lee County , Mississippi with his parents .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The band recorded an EP with Habeas Corpus , a song with Juan ( Agnostic Front ) and another with Roger Miret ( Soziedad Alcoholika ) in 2010 .
# Sentence 2: The band recorded an EP with Habeas Corpus in 2010 , a song with Roger Miret ( Agnostic Front ) and another one with Juan ( Soziedad Alkoholika )
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: His published works include a series of sermons written in `` Old Yet Ever New '' ( 1904 ) and `` Dayspring From On High '' ( 1907 ) .
# Sentence 2: His written works include a number of sermons published in `` Old Yet Ever New '' ( 1904 ) and `` Dayspring From On High '' ( 1907 ) .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Windsor -- Tecumseh was created in 2003 from parts of Windsor and the Essex -- St. Clair ridings .
# Sentence 2: Windsor -- Tecumseh was created in 2003 from parts of Windsor and the Essex -- St. Clair cattle .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The US 222 and the PA 724 meet in Spring Township and both meet in Wyomissing and Sinking Spring on US 422 .
# Sentence 2: US 222 and PA 724 meet in Spring Township and both meet US 422 in Wyomissing and Sinking Spring , respectively .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: `` Shine '' , the band 's second album , was released between two general dates and recorded 2009 .
# Sentence 2: The band 's second album , `` Shine '' , was recorded between two general data sets and released in 2009 .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Stefan Stefan would animate the `` Skumps '' sequence between Kings Hubert and John Lounsbery .
# Sentence 2: John Lounsbery would animate the `` Scumps '' sequence between Kings Hubert and Stefan .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: He is also the brother of the writer Ralph Connor and grandson of the novelist Alison Gordon .
# Sentence 2: He is also the brother of writer Alison Gordon and the grandson of novelist Ralph Connor .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Where is invariant mass and invariant energy equals . The squared mass is still positive and the particle can be stable .
# Sentence 2: Where is invariant mass and invariant energy the same , the squared mass is still positive and the particle can be stable .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: In 1976 , Western Forge delivered its 100 millionth Craftsman screwdriver , in 2008 the company produced its billionth screwdriver .
# Sentence 2: In 1976 , Western Forge shipped its 100 millionth Craftsman screwdriver . In 2008 , the company produced its billionth screwdriver overall .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: C2c uses Class 357 and Class 387 units on services down the London , Tilbury and Southend Railway line from Shoeburyness and Southend to London Fenchurch Street .
# Sentence 2: C2c uses Class 357 and Class 387 units on the London , Tilbury and Southend Railway tracks from London Fenchurch Street and Southend to Shoeburyness .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The competition started under JLT Sport as a sponsor , which continued last year .
# Sentence 2: The competition started as a sponsor under JLT Sport , which was continued last year .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The Olympic Committee of the Cayman Islands was founded in 1973 and was recognized by the International Olympic Committee ( IOC ) in 1976 .
# Sentence 2: The Olympic Committee of the Cayman Islands was founded in 1973 and was recognized by the IOC ( International Olympic Committee ) in 1976 .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: This was a series of nested polar scales , so that measurements in azimuth and elevation could be performed relative to the ecliptic directly in angle coordinates .
# Sentence 2: This was a series of nested angular standards , so that measurements in azimuth and elevation could be done directly in polar coordinates relative to the ecliptic .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Nearby Airport is Visakhapatnam Airport situated 185 km from Kashinagar . Other airports near Kashinagar
# Sentence 2: Kashinagar Airport is 185 km from Kashinagar other airports near Visakhapatnam Airport
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Rondônia ( River Juruá ) is a river in the state of Rondônia in western Brazil .
# Sentence 2: The Juruá River ( Rondônia ) is a river in the state of Rondônia in western Brazil .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: To read about the background to these events , see the history of Malaysia .
# Sentence 2: To read about the background to these events , see the history of Malaysia .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The Nationals wore the uniforms of the Washington Senators from 1924 on July 5 against the New York Giants , which wore the Giants - Uniforms of 1924 .
# Sentence 2: The Nationals wore the uniforms of the 1924 Washington Senators on July 5 against the New York Giants , who wore the 1924 Giants uniforms .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Adobe Premiere Express was a simple internet application for digital editing of extensive video files .
# Sentence 2: Adobe Premiere Express was a rich Internet application for simple editing of digital video files .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Giant Dipper was built by Arthur Looff and was designed by Frederick Church .
# Sentence 2: The Giant Dipper was designed by Arthur Looff and built by Frederick Church .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The episode was written by J. Stewart Burns and directed by Bret Haaland .
# Sentence 2: The episode was written by Bret Haaland and headed by J. Stewart Burns .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The Soviet Union was officially neutral until June 1941 in Asia , and until August 1945 in Europe , when it attacked Japan in cooperation with the U.S .
# Sentence 2: The Soviet Union was officially in Europe until June 1941 and officially neutral in Asia until August 1945 , when it attacked Japan in collaboration with the US .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1:

# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: 11206 Nizamabad Lokmanya Tilak Terminus Express reaches Nizamabad every Sunday at 23 : 15 hrs IST and leaves Lokmanya Tilak Terminus at 13 : 55 hrs IST the next day .
# Sentence 2: Nizamabad Lokmanya Tilak Terminus Express reaches Nizamabad every Sunday at 23 : 15 IST and leaves the Lokmanya Tilak Terminus at 13 : 55 IST the next day .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Although Huggins hoped to be elected as Cincinnati 's manager after the 1907 season as the successor of Ned Hanlon , the reds went with John Ganzel instead .
# Sentence 2: Although Ned Hanlon hoped to be elected as Cincinnati 's manager after the 1907 season as the successor to John Ganzel , the reds went with Huggins instead .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Clement Arundel `` Clem '' Newton-Brown ( born 3 September 1967 ) , Australian politician , is the former member for Prahran in the Victorian Legislative Assembly .
# Sentence 2: Clement Arundel `` Clem '' Newton-Brown ( born September 3 , 1967 ) , Victorian politician , is the former member of Prahran at the Australian legislative assembly .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Denise Foster is a survivor of an attack by Sanchez when she was 17 years old , near the railroad tracks in Buffalo , New York .
# Sentence 2: Sanchez is a survivor of an attack by Denise Foster when she was 17 years old , near the railway tracks in Buffalo , New York .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: After the Belgian Revolution of 1830 , the Southern Netherlands ( including South and Central Brabant ) became independent as Belgium and later also Luxembourg .
# Sentence 2: After the Belgian Revolution of 1830 , the South Netherlands ( including southern and central Brabant ) became independent as Belgium , and later Luxembourg .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Joshua Eagle and Andrew Florent won the title , defeating Sébastien Lareau and Jeff Tarango 6 -- 3 , 6 -- 2 in the final .
# Sentence 2: Sébastien Lareau and Jeff Tarango won the title and defeated Joshua Eagle and Andrew Florent with 6 -- 3 , 6 -- 2 in the final .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: This species occurs in the Pacific Ocean from Micronesia to Taiwan and from Thailand to Queensland , Australia .
# Sentence 2: This species is from Micronesia to Taiwan in the Pacific and from Thailand to Queensland , Australia .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Ruben Bolling ( * 1963 in New Jersey ) is a pseudonym for the cartoonist Ken Fisher , author of `` Tom the Dancing Bug '' .
# Sentence 2: Ken Fisher ( born c. 1963 in New Jersey ) is a pseudonym for Ruben Bolling , a cartoonist , the author of `` Tom the Dancing Bug '' .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: There are 2 further keys that differ in these 2 languages : Slovak key replaces the Czech key and Slovak key replaces the Czech key .
# Sentence 2: There are 2 more keys that differ in these 2 languages : Czech key replaces Czech key and Slovak key replaces Slovak key .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Of these eighteen countries , four of them have listed IN , PA , OH and MD `` G. villosa '' as endangered species .
# Sentence 2: Of these 18 states , four of them have listed IN , MD , OH and PA `` G. villosa '' as endangered species .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Java calls these types simple types , while they are called in C # `` Primitive Types '' .
# Sentence 2: Java calls these types primitive types , while they are called `` simple types '' in C # .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Soori is a 2001 Telugu film directed by debutant Sankara Kumar .
# Sentence 2: Soori is a 2001 Telugu movie directed by Debutant Sankara Kumar .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: James Alexander Hanson was born , the second son of James Trickett Hanson ( a Danish immigrant ) and Janet Scott .
# Sentence 2: Jim Marchbank was born James Alexander Hanson , the second son of James Trickett Hanson ( a Danish immigrant ) and Janet Scott .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Where formula _ 1 is the total surface energy of the solid , formula _ 1 and formula _ 1 are respectively the dispersive and polar components of the solid surface energy ,
# Sentence 2: Formula 1 is the solid surface energy of dispersive and polar , Formula 1 and Formula 1 respectively are the solid components of the overall surface energy .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Watchorn died on 3 April 1882 , and Fisher won the resulting May 1882 by-election comfortably .
# Sentence 2: Watchorn died on 3 April 1882 , and Fisher comfortably won the resulting May 1882 assistance .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: In Mississippi , unlike Alabama or Tennessee , MS 178 and US 78 are totally separate routes .
# Sentence 2: In Mississippi , MS 178 and US 78 are completely separate routes , unlike Alabama or Tennessee .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Twice Sparrow sold the island twice to Thomas Pollock , who would soon be the governor of North Carolina ( from 1712 to 1714 and again 1722 ) .
# Sentence 2: Sparrow twice sold the island to Thomas Pollock , who would soon be governor of North Carolina ( from 1712 to 1714 and again in 1722 ) .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Independencia is a central department of Chaco Province in Argentina .
# Sentence 2: Independencia is a central department of Argentina in the province of Chaco .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: She married Reinaldo Zamparelli in 1954 , living in Bogotá , Colombia and later in Lima , Peru .
# Sentence 2: In 1954 she married Reinaldo Zamparelli , lived in Lima , Peru and later in Bogotá , Colombia .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: Nesby Phips appeared in the documentary `` Mystery Lights '' , produced by Nowhere Studios , presented by Converse and released in the UK December 4 , 2015 .
# Sentence 2: Nesby Phips was released in the documentary `` Mystery Lights '' , presented by Nowhere Studios , produced by Converse and published in the UK on December 4 , 2015 .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: The name in Tupi means `` insensitive stone '' , `` hard stone '' or `` rest stone '' .
# Sentence 2: The name in Tupi means '' hard stone `` , '' insensitive stone `` or '' stone `` .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The company has branches in Tokyo , based in the Saitama prefecture .
# Sentence 2: The company has branches in Tokyo based in Saitama Prefecture .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Muara Teweh ( abbreviated : MTW ) is a city located in the province of North Barito Regency . It is the capital of Central Kalimantan .
# Sentence 2: Teweh ( abbreviated : MTW ) is a city located in the province of Central Kalimantan , the capital of North Barito Regency .
# True label: 0
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: The modern coat of arms of Bavaria was designed by Eduard Ege in 1946 , following heraldic traditions .
# Sentence 2: The modern coat of arms of Bavaria was designed in 1946 by Eduard Ege according to heraldic traditions .
# True label: 1
# Predicted label: 0
# --------------------------------------------------
# Sentence 1: Former President , Brenda Kuecks , received a Clean50 Award in 2013 for her work in promoting clean development and sustainable capitalism in Canada .
# Sentence 2: In 2013 , former President Brenda Kuecks received a Clean50 Award for her work to promote sustainable development and clean capitalism in Canada .
# True label: 0
# Predicted label: 1
# --------------------------------------------------
# Sentence 1: It is located near Point Pleasant Borough , a municipality of Point Pleasant Beach independent .
# Sentence 2: It is near Point Pleasant borough , a municipality independent of Point Pleasant Beach .
# True label: 1
# Predicted label: 1
# --------------------------------------------------
# Validation set performance:
#               precision    recall  f1-score   support
#
#            0       0.65      0.80      0.71      4461
#            1       0.64      0.45      0.53      3539
#
#     accuracy                           0.64      8000
#    macro avg       0.64      0.62      0.62      8000
# weighted avg       0.64      0.64      0.63      8000
#
#
# Test set performance:
#               precision    recall  f1-score   support
#
#            0       0.64      0.79      0.70      4464
#            1       0.62      0.43      0.51      3536
#
#     accuracy                           0.63      8000
#    macro avg       0.63      0.61      0.61      8000
# weighted avg       0.63      0.63      0.62      8000
#
# Test set accuracy: 0.631375
